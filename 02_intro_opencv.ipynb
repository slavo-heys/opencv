# %% [markdown]
# <a href="https://colab.research.google.com/github/slavo-heys/opencv/blob/main/02_intro_opencv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade opencv-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.9/dist-packages (4.7.0.72)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.9/dist-packages (from opencv-python) (1.22.4)

# %%
from google.colab.patches import cv2_imshow
import imutils
import numpy as np
import cv2

# %% [markdown]
# Zmiana rozmiaru zdjecia

# %%
img=cv2.imread('bear.jpg')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=586x480 at 0x7F924F32E190>

# %%
img_resized = imutils.resize(image=img, height=300)
cv2_imshow(img_resized)
# Out:
# <PIL.Image.Image image mode=RGB size=366x300 at 0x7F924F260160>

# %%
img_resized = imutils.resize(image=img, width=300)
cv2_imshow(img_resized)
# Out:
# <PIL.Image.Image image mode=RGB size=300x245 at 0x7F924F2607F0>

# %% [markdown]
# Rotacja

# %%
height, width = img.shape[:2]

M = cv2.getRotationMatrix2D(center=(height // 2, width // 2), angle=45, scale=1)
cv2_imshow(cv2.warpAffine(src=img, M=M, dsize=(width, height)))
# Out:
# <PIL.Image.Image image mode=RGB size=586x480 at 0x7F92409956A0>

# %% [markdown]
# Progowanie

# %%
gray = cv2.cvtColor(src=img, code=cv2.COLOR_BGR2GRAY)
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=586x480 at 0x7F92409FB6A0>

# %%
cv2_imshow(cv2.threshold(src=gray, thresh=50, maxval=255, type=cv2.THRESH_BINARY)[1])
# Out:
# <PIL.Image.Image image mode=L size=586x480 at 0x7F92409956D0>

# %%
kernel = np.ones(shape=(5,5), dtype=np.float32) / 25
kernel
# Out:
# array([[0.04, 0.04, 0.04, 0.04, 0.04],
#        [0.04, 0.04, 0.04, 0.04, 0.04],
#        [0.04, 0.04, 0.04, 0.04, 0.04],
#        [0.04, 0.04, 0.04, 0.04, 0.04],
#        [0.04, 0.04, 0.04, 0.04, 0.04]], dtype=float32)

# %% [markdown]
# Operacje splotu, wygladzanie

# %%
cv2_imshow(cv2.filter2D(src=img, ddepth=-1, kernel=kernel))
# Out:
# <PIL.Image.Image image mode=RGB size=586x480 at 0x7F924072C880>
